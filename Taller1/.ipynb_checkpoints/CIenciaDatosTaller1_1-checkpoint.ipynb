# %% [markdown]
# # Visualizar Bodega de datos

# %% [markdown]
# ## 1. Cargar Librerias

# %%
# Import the neccessary modules for data manipulation and visual representation
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
from matplotlib.pyplot import figure
# %matplotlib inline

# %% [markdown]
# ## 2. Conectar Python con PostgreSQL

# %%
from utils import new_model, engine #abrir el archivo conexion.py

# %% [markdown]
# ## 3. Comprobar la conexion a la bodega de datos

# %%
result = engine.execute('select * from dim_tiempo')
df_tiempo = pd.DataFrame(result.fetchall())
result = engine.execute('select * from dim_estacion')
df_estacion = pd.DataFrame(result.fetchall())
result = engine.execute('select * from dim_polutante')
df_polutante = pd.DataFrame(result.fetchall())
result = engine.execute('select * from fact_medidad')
df_medidas = pd.DataFrame(result.fetchall())

# %%
df_polutante
# Out:
#             id  PM10  PM2.5      NO    NO2     NOX        CO      OZONO
# 0            1  52.6   37.0  53.384  3.428  56.817  0.691233  11.782188
# 1            2  77.9   61.0  49.105  3.420  52.525  0.691233  11.782188
# 2            3  58.5   48.0  47.284  4.062  51.346  0.691233  11.782188
# 3            4  57.2   44.0  46.059  3.606  49.664  0.691233  11.782188
# 4            5  53.5   39.0  39.851  1.625  41.475  0.691233  11.782188
# ...        ...   ...    ...     ...    ...     ...       ...        ...
# 166435  166436  25.3   18.0   1.404  3.688   5.091  0.264670  29.773000
# 166436  166437  27.7   15.0   0.244  3.205   3.449  0.271380  28.059000
# 166437  166438  25.3   20.0   0.880  4.648   5.529  0.301590  25.561000
# 166438  166439  24.0   17.0   1.697  8.596  10.293  0.349770  20.539000
# 166439  166440  26.0   13.0   1.290  9.611  10.900  0.403000  16.285000
#
# [166440 rows x 8 columns]

# %% [markdown]
# ## 4. Visualizar datos desde la bodeda de datos

# %%
df_polutante['PM2.5'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot: >

# %%
df_polutante.hist(figsize=(16,10),facecolor='blue', alpha=0.9, bins=13, edgecolor='orange', linewidth=2)
plt.show()

# %%
#Correlation Matrix
del(df_polutante['id'])
corr = df_polutante.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
corr
# Out:
#            PM10     PM2.5        NO       NO2       NOX        CO     OZONO
# PM10   1.000000  0.759310  0.263536  0.334306  0.338860  0.459526 -0.032092
# PM2.5  0.759310  1.000000  0.278237  0.388426  0.368569  0.504338 -0.053075
# NO     0.263536  0.278237  1.000000  0.191043  0.952026  0.399196 -0.278493
# NO2    0.334306  0.388426  0.191043  1.000000  0.477759  0.382771 -0.312026
# NOX    0.338860  0.368569  0.952026  0.477759  1.000000  0.475125 -0.345144
# CO     0.459526  0.504338  0.399196  0.382771  0.475125  1.000000 -0.259279
# OZONO -0.032092 -0.053075 -0.278493 -0.312026 -0.345144 -0.259279  1.000000
