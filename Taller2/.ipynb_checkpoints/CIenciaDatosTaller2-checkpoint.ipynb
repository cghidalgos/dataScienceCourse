# %% [markdown]
# # Red de Monitoreo de Calidad del Aire de Bogota.
# http://rmcab.ambientebogota.gov.co/Report/stationreport

# %% [markdown]
# ## Descripción de los datos

# %% [markdown]
# ## 1. Cargar Librerias
# ***

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
from matplotlib.pyplot import figure
# %matplotlib inline

# %% [markdown]
# ## 2. Cargar Datos

# %%
#dataframe nombrado "df"
df = pd.read_csv('../Taller1/data/dataset_with_geo_missing.csv', sep=',', engine='python', encoding='latin1')
df
# Out:
#         PM10  PM2.5      NO    NO2     NOX       CO   OZONO Station  \
# 0       52.6   37.0  53.384  3.428  56.817      NaN     NaN     7MA
# 1       77.9   61.0  49.105  3.420  52.525      NaN     NaN     7MA
# 2       58.5   48.0  47.284  4.062  51.346      NaN     NaN     7MA
# 3       57.2   44.0  46.059  3.606  49.664      NaN     NaN     7MA
# 4       53.5   39.0  39.851  1.625  41.475      NaN     NaN     7MA
# ...      ...    ...     ...    ...     ...      ...     ...     ...
# 166435  25.3   18.0   1.404  3.688   5.091  0.26467  29.773     USQ
# 166436  27.7   15.0   0.244  3.205   3.449  0.27138  28.059     USQ
# 166437  25.3   20.0   0.880  4.648   5.529  0.30159  25.561     USQ
# 166438  24.0   17.0   1.697  8.596  10.293  0.34977  20.539     USQ
# 166439  26.0   13.0   1.290  9.611  10.900  0.40300  16.285     USQ
#
#                    DateTime  Status   Latitud   Longitud  month  day_week  \
# 0       2021-01-01 01:00:00    True  4.645117 -74.061503      1         4
# 1       2021-01-01 02:00:00    True  4.645117 -74.061503      1         4
# 2       2021-01-01 03:00:00    True  4.645117 -74.061503      1         4
# 3       2021-01-01 04:00:00    True  4.645117 -74.061503      1         4
# 4       2021-01-01 05:00:00    True  4.645117 -74.061503      1         4
# ...                     ...     ...       ...        ...    ...       ...
# 166435  2021-12-31 20:00:00    True  4.710381 -74.030414     12         4
# 166436  2021-12-31 21:00:00    True  4.710381 -74.030414     12         4
# 166437  2021-12-31 22:00:00    True  4.710381 -74.030414     12         4
# 166438  2021-12-31 23:00:00    True  4.710381 -74.030414     12         4
# 166439  2021-12-31 00:00:00    True  4.710381 -74.030414     12         4
#
#         day_month  hour
# 0               1     1
# 1               1     2
# 2               1     3
# 3               1     4
# 4               1     5
# ...           ...   ...
# 166435         31    20
# 166436         31    21
# 166437         31    22
# 166438         31    23
# 166439         31    24
#
# [166440 rows x 16 columns]

# %% [markdown]
# ## 3: Explorar datos
# ***

# %% [markdown]
# ###  3.1 Estadisticas
# ***
# Resumen:
# - Identificar nombre de las columnas
# - Número de columnas y filas
# - Tamaño del conjunto de datos
# - Tipos de datos
# - Porcentajes de valores
# - Correlaciones de variables
# - Valores nulos

# %%
#nombre de las columnas 
df.columns
# Out:
# Index(['PM10', 'PM2.5', 'NO', 'NO2', 'NOX', 'CO', 'OZONO', 'Station',
#        'DateTime', 'Status', 'Latitud', 'Longitud', 'month', 'day_week',
#        'day_month', 'hour'],
#       dtype='object')

# %%
# Estadisticas basicas del conjunto de datos 
df.describe()
# Out:
#                 PM10          PM2.5             NO            NO2  \
# count  146426.000000  151128.000000  138776.000000  138778.000000
# mean       31.978378      15.323489      18.616861      14.979247
# std        22.835375      12.467040      26.932382       9.233824
# min         0.000000       0.000000       0.000000       0.000000
# 25%        15.800000       6.000000       3.169000       7.515000
# 50%        26.700000      12.000000       7.759000      13.742000
# 75%        42.300000      21.600000      21.532000      20.626000
# max       326.200000     188.000000     341.104000      92.256000
#
#                  NOX             CO          OZONO        Latitud  \
# count  138772.000000  135202.000000  134308.000000  166440.000000
# mean       33.590300       0.691233      11.782188       4.653331
# std        30.056319       0.574689      10.133101       0.068116
# min         0.000000       0.000000       0.000000       4.532097
# 25%        13.109000       0.324885       3.458000       4.595958
# 50%        24.259000       0.520580       9.564000       4.645117
# 75%        43.472250       0.862195      17.518250       4.710381
# max       361.341000      12.025010      88.182000       4.783614
#
#             Longitud          month       day_week      day_month  \
# count  166440.000000  166440.000000  166440.000000  166440.000000
# mean      -74.104733       6.526027       3.002740      15.720548
# std         0.039154       3.447862       1.997948       8.796273
# min       -74.166272       1.000000       0.000000       1.000000
# 25%       -74.143714       4.000000       1.000000       8.000000
# 50%       -74.114869       7.000000       3.000000      16.000000
# 75%       -74.069472      10.000000       5.000000      23.000000
# max       -74.030414      12.000000       6.000000      31.000000
#
#                 hour
# count  166440.000000
# mean       12.500000
# std         6.922207
# min         1.000000
# 25%         6.750000
# 50%        12.500000
# 75%        18.250000
# max        24.000000

# %%
#Descripción del conjunto de datos: 166440 observaciones y 10 caracteristicas
df.shape
# Out:
# (166440, 16)

# %%
# Comprobar el número de Filas y Columnas 
print("Número de  Filas: ", len(df))
print("Número de Columnas ", + len(df.columns))

#Comprobar el tipo de datos en las características
print(df.dtypes)
# Out:
# Número de  Filas:  166440
# Número de Columnas  16
# PM10         float64
# PM2.5        float64
# NO           float64
# NO2          float64
# NOX          float64
# CO           float64
# OZONO        float64
# Station       object
# DateTime      object
# Status          bool
# Latitud      float64
# Longitud     float64
# month          int64
# day_week       int64
# day_month      int64
# hour           int64
# dtype: object

# %%
#Comprobar si hay valores nulos true o false
#df.isnull().any(1)

# %%
# Esta celda eliminará todas las filas que tienen valores nulos
#target = 'PM2.5'
#df.dropna(subset=[target], inplace=True)
#df.isnull().sum()

# %%
# Resumen de una variable (False V.S. True) en la variable Status
Status_Summary = df.groupby('Status')
Status_Summary.mean()
# Out:
# /tmp/ipykernel_15617/2268325974.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Status_Summary.mean()
#              PM10      PM2.5         NO        NO2        NOX        CO  \
# Status
# False   19.386094   6.078521  12.052512  11.560457  23.608207  0.489511
# True    45.786601  24.622938  26.674421  19.175339  45.843120  0.925081
#
#             OZONO   Latitud   Longitud     month  day_week  day_month  \
# Status
# False   12.410797  4.658403 -74.097233  6.228633  3.016191  15.493359
# True    11.054208  4.647198 -74.113800  6.885615  2.986475  15.995248
#
#              hour
# Status
# False   12.556302
# True    12.431924

# %%
#Filtrar datos por columnas
df['Status'] = df['PM2.5']>12
df.Status.value_counts()
# Out:
# False    91098
# True     75342
# Name: Status, dtype: int64

# %% [markdown]
# ####  3.1.1 Correlación
# ***
#
# Resumen:
#
#
# - Hay una correlación **positiva(+) a 1** o **negativa(-) a -1** hay una correlacion fuerte. La aproximación a 0 es mas debil la relacion lineal

# %%
#Matriz de correlación
corr = df.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
corr
# Out:
# /tmp/ipykernel_15617/3316224346.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#                PM10     PM2.5        NO       NO2       NOX        CO  \
# PM10       1.000000  0.802069  0.335233  0.428925  0.432756  0.540299
# PM2.5      0.802069  1.000000  0.336237  0.476576  0.447956  0.574157
# NO         0.335233  0.336237  1.000000  0.191053  0.953439  0.644717
# NO2        0.428925  0.476576  0.191053  1.000000  0.477839  0.566374
# NOX        0.432756  0.447956  0.953439  0.477839  1.000000  0.728551
# CO         0.540299  0.574157  0.644717  0.566374  0.728551  1.000000
# OZONO     -0.036996 -0.060233 -0.394073 -0.360669 -0.440935 -0.300301
# Status     0.577450  0.743737  0.270038  0.410184  0.367955  0.377931
# Latitud   -0.155079 -0.112961 -0.007868 -0.061925 -0.026439 -0.251042
# Longitud  -0.347390 -0.250248  0.083764 -0.299016 -0.017102 -0.254375
# month      0.066571  0.057089  0.071778  0.135322  0.105715  0.051042
# day_week  -0.048476 -0.027135 -0.037936 -0.060067 -0.052408 -0.032911
# day_month  0.025091  0.024499  0.018078  0.039308  0.028391  0.015427
# hour      -0.000334 -0.017080 -0.088337  0.078106 -0.054962  0.065223
#
#               OZONO    Status       Latitud      Longitud         month  \
# PM10      -0.036996  0.577450 -1.550795e-01 -3.473899e-01  6.657095e-02
# PM2.5     -0.060233  0.743737 -1.129608e-01 -2.502483e-01  5.708923e-02
# NO        -0.394073  0.270038 -7.867772e-03  8.376409e-02  7.177750e-02
# NO2       -0.360669  0.410184 -6.192456e-02 -2.990163e-01  1.353222e-01
# NOX       -0.440935  0.367955 -2.643948e-02 -1.710197e-02  1.057147e-01
# CO        -0.300301  0.377931 -2.510423e-01 -2.543754e-01  5.104225e-02
# OZONO      1.000000 -0.066759  4.032082e-03  7.008171e-02 -5.755124e-02
# Status    -0.066759  1.000000 -8.187885e-02 -2.106090e-01  9.484627e-02
# Latitud    0.004032 -0.081879  1.000000e+00  4.692984e-01  8.908049e-15
# Longitud   0.070082 -0.210609  4.692984e-01  1.000000e+00 -3.009967e-13
# month     -0.057551  0.094846  8.908049e-15 -3.009967e-13  1.000000e+00
# day_week   0.036110 -0.007403  2.106458e-15 -1.275715e-14 -8.561297e-03
# day_month -0.003484  0.028401  2.677347e-15 -4.115892e-14  1.189318e-02
# hour       0.135267 -0.008944  1.007148e-15 -2.318190e-15 -3.552617e-16
#
#                day_week     day_month          hour
# PM10      -4.847605e-02  2.509053e-02 -3.340085e-04
# PM2.5     -2.713513e-02  2.449874e-02 -1.707986e-02
# NO        -3.793585e-02  1.807825e-02 -8.833711e-02
# NO2       -6.006695e-02  3.930810e-02  7.810594e-02
# NOX       -5.240819e-02  2.839067e-02 -5.496240e-02
# CO        -3.291148e-02  1.542728e-02  6.522312e-02
# OZONO      3.611003e-02 -3.483552e-03  1.352671e-01
# Status    -7.403341e-03  2.840050e-02 -8.943683e-03
# Latitud    2.106458e-15  2.677347e-15  1.007148e-15
# Longitud  -1.275715e-14 -4.115892e-14 -2.318190e-15
# month     -8.561297e-03  1.189318e-02 -3.552617e-16
# day_week   1.000000e+00  1.625644e-02  5.675824e-18
# day_month  1.625644e-02  1.000000e+00  2.388572e-17
# hour       5.675824e-18  2.388572e-17  1.000000e+00

# %% [markdown]
# ###  3.2 Gráficos de distribución

# %%
#hist es un grafico (pandas) de distribucion de  datos.
#este grafico nos sirve para identificar cuales son las variables numericas y su frencuencia. 

df.hist(figsize=(16,10),facecolor='blue', alpha=0.9, bins=13, edgecolor='orange', linewidth=2)
plt.show()

# %%
#otra forma de ver la distribucion de los datos
# Uso de Libreria Seaborn (sna) para poner multiples graficos de distribución  
f, axes = plt.subplots(ncols=3, figsize=(15, 6))

#variable PM10
sns.distplot(df.PM10, kde=False, color="g", ax=axes[0]).set_title('PM10')

#variable PM10
sns.distplot(df.Status, kde=False, color="r", ax=axes[1]).set_title('Status')

#variable NOX
sns.distplot(df.NOX, kde=False, color="b", ax=axes[2]).set_title('NOX')
# Out:
# /tmp/ipykernel_15617/1448057234.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.PM10, kde=False, color="g", ax=axes[0]).set_title('PM10')
# /tmp/ipykernel_15617/1448057234.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Status, kde=False, color="r", ax=axes[1]).set_title('Status')
# /tmp/ipykernel_15617/1448057234.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.NOX, kde=False, color="b", ax=axes[2]).set_title('NOX')
# Text(0.5, 1.0, 'NOX')

# %% [markdown]
# ###  3.3 Gráfico de barras

# %%
#ditribucion por estacion 
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(x="Station", hue='Status', data=df).set_title('Distribución de Station');

# %%
# Types of colors
color_types = ['#78C850','#F08030','#6890F0','#A8B820','#A8A878','#A040A0','#F8D030',  
                '#E0C068','#EE99AC','#C03028','#F85888','#B8A038','#705898','#98D8D8','#7038F8' ,'#FFFFF']

# Count Plot (a.k.a. Bar Plot)
sns.countplot(y='Station', data=df).set_title('Distribución por Estación');
 
# Rotate x-labels
plt.xticks(rotation=-45)
# Out:
# (array([    0.,  2000.,  4000.,  6000.,  8000., 10000.]),
#  [Text(0.0, 0, '0'),
#   Text(2000.0, 0, '2000'),
#   Text(4000.0, 0, '4000'),
#   Text(6000.0, 0, '6000'),
#   Text(8000.0, 0, '8000'),
#   Text(10000.0, 0, '10000')])

# %% [markdown]
# ###  3.4 Gráficos de Cajas

# %%
import seaborn as sns

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.boxplot(x="Station", y="PM2.5",  data=df)
valh=4
plt.axhline(valh, color='red')

# %% [markdown]
# Hemos revisado la información de ded dataset "calidad del aire", donde es importante la estación que mide la calidad del aire, sin embargo, no tenemos donde esta ubicada.
#
# Ahora vamos a cargar un nuevo dataset, que contiene la infromación de la ubicación (Latitud, Longitud) de cada estación.

# %% [markdown]
# ## 4. Tecnicas para solucionar valores perdidos y anomalias en un dataset

# %%
#Contar valores nulos por columnas
df.isnull().sum()
# Out:
# PM10         20014
# PM2.5        15312
# NO           27664
# NO2          27662
# NOX          27668
# CO           31238
# OZONO        32132
# Station          0
# DateTime         0
# Status           0
# Latitud          0
# Longitud         0
# month            0
# day_week         0
# day_month        0
# hour             0
# dtype: int64

# %%
## Hay 74803 valores NaN de 166440
nan_rows = df[df.isnull().any(1)]
nan_rows
# Out:
# /tmp/ipykernel_15617/2863028832.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   nan_rows = df[df.isnull().any(1)]
#         PM10  PM2.5      NO    NO2     NOX       CO   OZONO Station  \
# 0       52.6   37.0  53.384  3.428  56.817      NaN     NaN     7MA
# 1       77.9   61.0  49.105  3.420  52.525      NaN     NaN     7MA
# 2       58.5   48.0  47.284  4.062  51.346      NaN     NaN     7MA
# 3       57.2   44.0  46.059  3.606  49.664      NaN     NaN     7MA
# 4       53.5   39.0  39.851  1.625  41.475      NaN     NaN     7MA
# ...      ...    ...     ...    ...     ...      ...     ...     ...
# 166119   8.2    NaN   3.016  3.132   6.148  0.23806  18.809     USQ
# 166277   NaN    8.0   6.349  7.900  14.249  0.34390   7.896     USQ
# 166322   NaN   16.0   1.176  5.196   6.372  0.23339  10.659     USQ
# 166367   NaN   17.0   6.271  8.220  14.491  0.36351  12.266     USQ
# 166425   NaN   20.0   2.127  2.790   4.917  0.14834  25.527     USQ
#
#                    DateTime  Status   Latitud   Longitud  month  day_week  \
# 0       2021-01-01 01:00:00    True  4.645117 -74.061503      1         4
# 1       2021-01-01 02:00:00    True  4.645117 -74.061503      1         4
# 2       2021-01-01 03:00:00    True  4.645117 -74.061503      1         4
# 3       2021-01-01 04:00:00    True  4.645117 -74.061503      1         4
# 4       2021-01-01 05:00:00    True  4.645117 -74.061503      1         4
# ...                     ...     ...       ...        ...    ...       ...
# 166119  2021-12-18 16:00:00   False  4.710381 -74.030414     12         5
# 166277  2021-12-25 06:00:00   False  4.710381 -74.030414     12         5
# 166322  2021-12-27 03:00:00    True  4.710381 -74.030414     12         0
# 166367  2021-12-28 00:00:00    True  4.710381 -74.030414     12         1
# 166425  2021-12-31 10:00:00    True  4.710381 -74.030414     12         4
#
#         day_month  hour
# 0               1     1
# 1               1     2
# 2               1     3
# 3               1     4
# 4               1     5
# ...           ...   ...
# 166119         18    16
# 166277         25     6
# 166322         27     3
# 166367         28    24
# 166425         31    10
#
# [74803 rows x 16 columns]

# %% [markdown]
# ### 4.1 Completar con la media, mediana o desviación estándar

# %%
df.describe()
# Out:
#                 PM10          PM2.5             NO            NO2  \
# count  146426.000000  151128.000000  138776.000000  138778.000000
# mean       31.978378      15.323489      18.616861      14.979247
# std        22.835375      12.467040      26.932382       9.233824
# min         0.000000       0.000000       0.000000       0.000000
# 25%        15.800000       6.000000       3.169000       7.515000
# 50%        26.700000      12.000000       7.759000      13.742000
# 75%        42.300000      21.600000      21.532000      20.626000
# max       326.200000     188.000000     341.104000      92.256000
#
#                  NOX             CO          OZONO        Latitud  \
# count  138772.000000  135202.000000  134308.000000  166440.000000
# mean       33.590300       0.691233      11.782188       4.653331
# std        30.056319       0.574689      10.133101       0.068116
# min         0.000000       0.000000       0.000000       4.532097
# 25%        13.109000       0.324885       3.458000       4.595958
# 50%        24.259000       0.520580       9.564000       4.645117
# 75%        43.472250       0.862195      17.518250       4.710381
# max       361.341000      12.025010      88.182000       4.783614
#
#             Longitud          month       day_week      day_month  \
# count  166440.000000  166440.000000  166440.000000  166440.000000
# mean      -74.104733       6.526027       3.002740      15.720548
# std         0.039154       3.447862       1.997948       8.796273
# min       -74.166272       1.000000       0.000000       1.000000
# 25%       -74.143714       4.000000       1.000000       8.000000
# 50%       -74.114869       7.000000       3.000000      16.000000
# 75%       -74.069472      10.000000       5.000000      23.000000
# max       -74.030414      12.000000       6.000000      31.000000
#
#                 hour
# count  166440.000000
# mean       12.500000
# std         6.922207
# min         1.000000
# 25%         6.750000
# 50%        12.500000
# 75%        18.250000
# max        24.000000

# %%
#Para todo el conjunto de datos 
df_1 = df.fillna(df.std())
df_1.iloc[0]


#Para una sola columna

#df_1 = df['PM10'].fillna((df['PM10'].std()), inplace=True)
# Out:
# /tmp/ipykernel_15617/1438930664.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1 = df.fillna(df.std())
# PM10                        52.6
# PM2.5                       37.0
# NO                        53.384
# NO2                        3.428
# NOX                       56.817
# CO                      0.574689
# OZONO                  10.133101
# Station                      7MA
# DateTime     2021-01-01 01:00:00
# Status                      True
# Latitud                 4.645117
# Longitud              -74.061503
# month                          1
# day_week                       4
# day_month                      1
# hour                           1
# Name: 0, dtype: object

# %%
df_1.isnull().sum()
# Out:
# PM10         0
# PM2.5        0
# NO           0
# NO2          0
# NOX          0
# CO           0
# OZONO        0
# Station      0
# DateTime     0
# Status       0
# Latitud      0
# Longitud     0
# month        0
# day_week     0
# day_month    0
# hour         0
# dtype: int64

# %% [markdown]
# ### 4.2 Completar con valor predeterminada

# %%
df_2 = df.fillna(25)
df_2.iloc[0]
# Out:
# PM10                        52.6
# PM2.5                       37.0
# NO                        53.384
# NO2                        3.428
# NOX                       56.817
# CO                          25.0
# OZONO                       25.0
# Station                      7MA
# DateTime     2021-01-01 01:00:00
# Status                      True
# Latitud                 4.645117
# Longitud              -74.061503
# month                          1
# day_week                       4
# day_month                      1
# hour                           1
# Name: 0, dtype: object

# %%
df_2.isnull().sum()
# Out:
# PM10         0
# PM2.5        0
# NO           0
# NO2          0
# NOX          0
# CO           0
# OZONO        0
# Station      0
# DateTime     0
# Status       0
# Latitud      0
# Longitud     0
# month        0
# day_week     0
# day_month    0
# hour         0
# dtype: int64

# %% [markdown]
# ### 4.3 Eliminar NaN

# %%
#Elinina todas las filas que tengan NaN
df_3 = nan_rows.dropna()

# %%
df_3.isnull().sum()
# Out:
# PM10         0.0
# PM2.5        0.0
# NO           0.0
# NO2          0.0
# NOX          0.0
# CO           0.0
# OZONO        0.0
# Station      0.0
# DateTime     0.0
# Status       0.0
# Latitud      0.0
# Longitud     0.0
# month        0.0
# day_week     0.0
# day_month    0.0
# hour         0.0
# dtype: float64

# %% [markdown]
# ## 5. Completar datos con Modelos de Machine Learning

# %% [markdown]
# ### Instalar Librerias

# %%
#pip install folium
#pip install sklearn
#pip install matplotlib
#pip install seaborn

# %% [markdown]
# ### Cargar Librerias

# %%
import os, re
import numpy as np

import pandas as pd

import folium 
from folium.plugins import FastMarkerCluster
 
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from utils import *

from sklearn.model_selection import train_test_split,StratifiedShuffleSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Cargar dataset

# %%
#dataframe nombrado "df"
df = pd.read_csv('../Taller1/data/dataset_with_geo_missing.csv', sep=',', engine='python', encoding='latin1')
df.head(3)
# Out:
#    PM10  PM2.5      NO    NO2     NOX  CO  OZONO Station             DateTime  \
# 0  52.6   37.0  53.384  3.428  56.817 NaN    NaN     7MA  2021-01-01 01:00:00
# 1  77.9   61.0  49.105  3.420  52.525 NaN    NaN     7MA  2021-01-01 02:00:00
# 2  58.5   48.0  47.284  4.062  51.346 NaN    NaN     7MA  2021-01-01 03:00:00
#
#    Status   Latitud   Longitud  month  day_week  day_month  hour
# 0    True  4.645117 -74.061503      1         4          1     1
# 1    True  4.645117 -74.061503      1         4          1     2
# 2    True  4.645117 -74.061503      1         4          1     3

# %%
#Para este ejemplo, vamos a llenar con la media todas las filas excepto la de PM2.5
df.isnull().sum()
# Out:
# PM10         20014
# PM2.5        15312
# NO           27664
# NO2          27662
# NOX          27668
# CO           31238
# OZONO        32132
# Station          0
# DateTime         0
# Status           0
# Latitud          0
# Longitud         0
# month            0
# day_week         0
# day_month        0
# hour             0
# dtype: int64

# %%
df['PM10'].fillna((df['PM10'].mean()), inplace=True)
#df['PM2.5'].fillna((df['PM2.5'].mean()), inplace=True) Menos esta columna
df['CO'].fillna((df['CO'].mean()), inplace=True)
df['NO'].fillna((df['NO'].mean()), inplace=True)
df['NO2'].fillna((df['NO2'].mean()), inplace=True)
df['NOX'].fillna((df['NOX'].mean()), inplace=True)
df['OZONO'].fillna((df['OZONO'].mean()), inplace=True)

# %%
df.isnull().sum()
# Out:
# PM10             0
# PM2.5        15312
# NO               0
# NO2              0
# NOX              0
# CO               0
# OZONO            0
# Station          0
# DateTime         0
# Status           0
# Latitud          0
# Longitud         0
# month            0
# day_week         0
# day_month        0
# hour             0
# dtype: int64

# %% [markdown]
# ## 5.1 Explicando las brechas pequeñas frente a las brechas grandes
#
# En el siguiente ejemplo se puede ver el problema que queremos resolver. Tiene una serie de valores para un solo día de mediciones, y allí falta un valor. Coloreamos el valor faltante en rojo.
# Existen varias opciones para imputar un valor que complete la serie. Algunas son realmente simples, como usar el promedio de todos los puntos conocidos para la variable (ver punto anterior).

# %%
rows_of_day = df.apply(lambda row : row['month'] == 3 and row['day_month'] == 6 and row['Station']=='7MA', axis=1)
single_day_df = df[rows_of_day]
figure(figsize=(10, 5), dpi=80)
draw_example(single_day_df, [12], False, 'Down period of size 1')

# %% [markdown]
# Ahora, a veces los períodos de inactividad son más largos que un solo paso de tiempo. En tales casos, completar los valores que faltan puede ser más difícil que en el caso anterior.

# %%
figure(figsize=(10, 5), dpi=80)
draw_example(single_day_df, [12, 13, 14, 15], False, 'Down period of size 4')

# %% [markdown]
# #### Ejemplo de un buen ajuste (fit)

# %%
figure(figsize=(10, 5), dpi=80)
draw_example(single_day_df, [12])

# %% [markdown]
# #### Ejemplo de un mal ajuste (fit)

# %%
figure(figsize=(10, 5), dpi=80)
draw_example(single_day_df, list(range(3, 18)))

# %%
# This cell will delete all the rows which have Null values
target = 'PM2.5'
df_with_missing = df.copy()   # Save a copy with missing values
df.dropna(subset=[target], inplace=True)
df.isnull().sum()
# Out:
# PM10         0
# PM2.5        0
# NO           0
# NO2          0
# NOX          0
# CO           0
# OZONO        0
# Station      0
# DateTime     0
# Status       0
# Latitud      0
# Longitud     0
# month        0
# day_week     0
# day_month    0
# hour         0
# dtype: int64

# %% [markdown]
# ## 5.2 Aplicación del modelo lineal
#
#
# ### Dividir en Entrenamiento/Prueba
#
# Para entrenar un modelo de regresión lineal, debe dividir sus datos en conjuntos de entrenamiento y prueba. El conjunto de entrenamiento es con lo que creará una línea de mejor ajuste (Best Fit). Luego probará qué tan bien está su modelo comparando las predicciones de su modelo de regresión lineal con los datos reales.
#
# <img src="img/split_data.png" alt="datos_divididos" width="400"/>
#
# <center><b>Figura 1:</b> División de datos en conjuntos de entrenamiento y prueba </center>
#
# Mezclará el conjunto de datos completo y dividirá sus datos de Bogotá en conjuntos de entrenamiento y prueba para la regresión lineal. Esto simulará el caso cuando tenga valores faltantes en sus datos en momentos aleatorios.
#
# Divida el conjunto de datos ejecutando la siguiente celda de código:

# %%
# Split into train and test
train_df, test_df = train_test_split(df, test_size=0.20, random_state=42)

# %% [markdown]
# ### Métricas de evaluación
#
# **Las métricas de evaluación lo ayudan a comprender qué están haciendo bien sus modelos y qué les falta.** En general, usará un conjunto de datos para entrenar el modelo (`train_df`), y usará otro conjunto de datos para evaluar el rendimiento del modelo (`test_df`).
#
# Puede utilizar el error cuadrático medio (MSE) para evaluar el rendimiento de un modelo cuando la salida es una variable continua, como la concentración de PM2.5.
#
# <img src="img/MSE.png" alt="MSE" width="250"/>
#
# <center><b>Figura 3:</b> Error cuadrático medio </center>
#
# MSE mide la distancia (Figura 3) entre el valor real (puntos grises) y el valor predicho (línea azul), luego penaliza los errores grandes al elevar al cuadrado la distancia. Nuevamente, no se preocupe por los detalles de MSE, solo sepa que es una métrica común para evaluar el rendimiento.
#
# MSE no es la única forma de medir el rendimiento de un modelo. Puedes usar otros como:
#
# - **Error absoluto medio:** Muy similar a MSE, pero las distancias no están elevadas al cuadrado.
# - **Coeficiente de determinación**, denotado por R2, es la proporción de la variación en la variable dependiente que es predecible a partir de la variable independiente.
#
#
# <details>
#   <summary><span style="color:blue">¿Está interesado en las fórmulas? Haga clic aquí</span></summary>
# $$MSE = \frac{1}{N} \sum_{i=1}^{N}{(y_i - pred_i)^2}$$
#
# $$MAE = \frac{1}{N} \sum_{i=1}^{N}{|y_i - pred_i|}$$
#
# Donde N es el número de muestras en el conjunto de prueba  (`test_df`)
#
# </details>

# %% [markdown]
# ### Estableciendo una línea base
#
# Una buena estrategia para entrenar modelos de IA consiste en crear modelos simples que refinas iterativamente hasta obtener un modelo final. Establecer una línea de base sólida es clave en el resto del proceso porque ayuda a determinar si su modelo realmente está aportando algo interesante o simplemente es una pérdida de tiempo y recursos. En nuestro caso, estamos interesados en métodos que nos ayuden a completar los valores que faltan.
# Entonces, antes de crear su primer modelo que use el aprendizaje automático, utilizará 2 métodos simples para completar los valores faltantes. En el primer método, reemplazará cada valor faltante por la media o la mediana de la variable objetivo; el segundo método utilizará la mediana de cada estación para ese propósito. La implementación es muy sencilla y ya está implementada en Sklearn como uno de los métodos para la imputación de valores faltantes.
#
# Tratemos de establecer nuestra línea de base.

# %%
regression_scores = {}

regression_scores['global_mean'] = missing_values_imputation_mean(train_df, test_df, 'PM2.5')
regression_scores['local_mean'] =  missing_values_imputation_mean_by_station(train_df, test_df,'PM2.5')    

print('Desempeño usando la media global')
print(regression_scores['global_mean'])
print('\nDesempeño usando la media por estation')
print(regression_scores['local_mean'])
# Out:
# Desempeño usando la media global
# {'mse': 156.97398385813017, 'mae': 9.550823844818149}
#
# Desempeño usando la media por estation
# {'mse': 127.28405346106373, 'mae': 8.55618921096844}

# %% [markdown]
# ### Regresión lineal
#
# **El ajuste de curvas** es una excelente forma de modelar datos de series temporales e implica ajustar una función a los datos y usarla para predecir los siguientes valores. Esencialmente, el punto es tratar de encontrar la función matemática que sigue mejor a los puntos de datos.
#
# **La regresión lineal** es un tipo de ajuste de curva que intenta modelar la relación entre dos variables o características ajustando una ecuación lineal a los datos. ¡Esencialmente, está tratando de ajustar una línea recta a los datos que tiene!
#
# <img src="img/linear.png" alt="regresión lineal" width="300"/>
#
# <center><b>Figura 2:</b> Regresión lineal </center>
#
# Encontrar la *línea de mejor ajuste* implica usar la ecuación `y = ax + b` que encuentra la relación entre las siguientes variables:
# - `y`: el eje vertical. Representa PM2.5.
# - `x`: el eje horizontal. Representa características (por ejemplo, mes, día/semana, hora, etc.).
# - `a`: la pendiente, que determina el ángulo de la línea. Una pendiente más alta significa que el valor de PM2.5 está aumentando a un *ritmo* más rápido.
# - `b`: determina qué tan alto o bajo llega la línea al eje y.

# %%
# You will call this function multiple times in this notebook. Think of this function as a tool which will take the data,
# fit into the Linear Regression Model and Evaluate
from sklearn.preprocessing import StandardScaler

def regression_model(feature_names, target, model):
    '''
    This function will take the features(x), the target(y) and the model name (Linear Regression)
    and will fit the data into the model (train your data using Linear Regression) 
    and Evaluate by returning the mean squared error and the mean absolute error 
    '''
    scaler = StandardScaler()

    #print(f"Features: {feature_names}\nTarget: {target}")
    
    X_train = train_df[feature_names]
    scaler.fit(X_train)
    
    X_train = scaler.transform(X_train)
    y_train = train_df[target]
    
    X_test = test_df[feature_names]
    X_test = scaler.transform(X_test)
    
    y_test = test_df[target]

    # Print out the shapes
    #print(f"\nX Train Shape:{X_train.shape}\ny Train Shape: {y_train.shape}\nX Test Shape: {X_test.shape}\ny Test Shape: {y_test.shape}")
    
    # Build and train model
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"\nModel Score: {model.score(X_test, y_test)}")
    
    return {"MSE": mean_squared_error(y_pred, y_test), "MAE": mean_absolute_error(y_pred, y_test)}

# %%
from sklearn.neural_network import MLPRegressor

model = MLPRegressor(hidden_layer_sizes=(64, 32), learning_rate_init=0.07, verbose=True)
regression_scores_MLP = {}
target = 'PM2.5'
#feature_names = ['hour', 'day_week']
    
feature_names = ['hour', 'day_week'] +  ['Latitud', 'Longitud'] + ['PM10','CO','NO2','NOX','NO','OZONO']
    
regression_scores_MLP['model_with_day_hour'] = regression_model(feature_names, target, model)

print(regression_scores_MLP['model_with_day_hour'])
# Out:
# Iteration 1, loss = 28.09538034
# Iteration 2, loss = 25.06192253
# Iteration 3, loss = 24.41799053
# Iteration 4, loss = 24.03033000
# Iteration 5, loss = 24.30208941
# Iteration 6, loss = 24.11007205
# Iteration 7, loss = 23.83350374
# Iteration 8, loss = 23.95886147
# Iteration 9, loss = 23.75631587
# Iteration 10, loss = 23.72776387
# Iteration 11, loss = 23.53170942
# Iteration 12, loss = 23.66072401
# Iteration 13, loss = 23.53166560
# Iteration 14, loss = 23.63263931
# Iteration 15, loss = 23.45543917
# Iteration 16, loss = 23.42338393
# Iteration 17, loss = 23.54429737
# Iteration 18, loss = 23.35756488
# Iteration 19, loss = 23.39933576
# Iteration 20, loss = 23.44511409
# Iteration 21, loss = 23.55476772
# Iteration 22, loss = 23.52974404
# Iteration 23, loss = 23.80621574
# Iteration 24, loss = 23.57382354
# Iteration 25, loss = 23.51550073
# Iteration 26, loss = 23.40808887
# Iteration 27, loss = 23.67257982
# Iteration 28, loss = 23.63123541
# Iteration 29, loss = 23.30660659
# Iteration 30, loss = 23.32092550
# Iteration 31, loss = 23.40342262
# Iteration 32, loss = 23.20090174
# Iteration 33, loss = 23.28906148
# Iteration 34, loss = 23.38401651
# Iteration 35, loss = 23.32436702
# Iteration 36, loss = 23.85806772
# Iteration 37, loss = 23.37603086
# Iteration 38, loss = 23.34592977
# Iteration 39, loss = 23.70725992
# Iteration 40, loss = 23.49397123
# Iteration 41, loss = 23.29882801
# Iteration 42, loss = 23.29755723
# Iteration 43, loss = 23.24815754
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
# Model Score: 0.701947494944684
# {'MSE': 46.7862143906593, 'MAE': 4.910154214743857}

# %%
from matplotlib.pyplot import figure

def draw_example2(sample, predicted2, missing_index):
    missing = missing_index
    missing_before_after = [missing[0]-1]+missing+[missing[-1]+1]

    example1 = sample.copy()
    example1.loc[example1['hour'].isin(missing),'PM2.5'] = float('NaN')
    plt.plot(missing_before_after,  sample[sample['hour'].isin(missing_before_after)]['PM2.5'] , 'r--o')

    example1['newPM2.5'] = example1['PM2.5'].interpolate(method='linear')

    plt.plot(missing_before_after, example1[example1['hour'].isin(missing_before_after)]['newPM2.5'], 'g--o')
    plt.plot(example1['hour'], example1['PM2.5'], '-*')
    
    example1['nnPM2.5'] = sample['PM2.5'].copy()
    example1.loc[example1['hour'].isin(missing), 'nnPM2.5'] = predicted2[np.array(missing)-1]
    plt.plot(missing_before_after, example1.loc[example1['hour'].isin(missing_before_after)]['nnPM2.5'], 'y--*')
    
    plt.xlabel('hour')
    plt.ylabel('PM2.5')
    plt.title('Single day real data and predictions')

# %%
#rows_of_day = df.apply(lambda row : row['month'] == 11 and row['day_month'] == 3 and row['Station']=='USQ', axis=1)
rows_of_day = df.apply(lambda row : row['month'] == 11 and row['day_month'] == 6 and row['Station']=='USQ', axis=1)

single_day_df = df[rows_of_day]

scaler = StandardScaler()
X_train = train_df[feature_names]
scaler.fit(X_train)

X_test = single_day_df[feature_names]
X_test = scaler.transform(X_test)
y_test = single_day_df[target]

y_predicted = model.predict(X_test)
#y_predicted_DT = model.predict(X_test)

figure(figsize=(10, 5), dpi=80)
draw_example2(single_day_df, y_predicted, [12])

# %%
figure(figsize=(10, 5), dpi=80)
draw_example2(single_day_df,y_predicted, list(range(3, 18)))

# %% [markdown]
# ### Probando con Árbol de Decisión

# %%
from sklearn import tree

model = tree.DecisionTreeRegressor()
regression_scores_DT = {}
target = 'PM2.5'
#feature_names = ['hour', 'day_week']
    
feature_names = ['hour', 'day_week'] +  ['Latitud', 'Longitud'] + ['PM10','CO','NO2','NOX','NO','OZONO']
    
regression_scores_DT['model_with_day_hour'] = regression_model(feature_names, target, model)

print(regression_scores_DT['model_with_day_hour'])
# Out:
# Model Score: 0.4750678576886548
# {'MSE': 82.40020578310065, 'MAE': 6.327621914907696}

# %%
#rows_of_day = df.apply(lambda row : row['month'] == 11 and row['day_month'] == 3 and row['Station']=='USQ', axis=1)
rows_of_day = df.apply(lambda row : row['month'] == 11 and row['day_month'] == 6 and row['Station']=='USQ', axis=1)

single_day_df = df[rows_of_day]

scaler = StandardScaler()
X_train = train_df[feature_names]
scaler.fit(X_train)

X_test = single_day_df[feature_names]
X_test = scaler.transform(X_test)
y_test = single_day_df[target]

y_predicted = model.predict(X_test)
#y_predicted_DT = model1.predict(X_test)

figure(figsize=(10, 5), dpi=80)
draw_example2(single_day_df, y_predicted, [12])

# %%
figure(figsize=(10, 5), dpi=80)
draw_example2(single_day_df,y_predicted, list(range(3, 18)))

# %% [markdown]
# ## 6. Ajuste de parámetros, Búsqueda por cuadrícula, Validación cruzada
#
# Los hiperparámetros son parámetros ajustables que permiten controlar el proceso de entrenamiento de un modelo. Por ejemplo, con redes neuronales, puede decidir el número de capas ocultas y el número de nodos de cada capa. ...El rendimiento de un modelo depende en gran medida de los hiperparámetros.
#
# Es posible y recomendable buscar en el espacio de hiperparámetros para obtener la mejor validación cruzada, es decir, evaluar la puntuación de rendimiento del modelo.
#
# Cualquier parámetro proporcionado al construir un modelo puede optimizarse de esta manera. Específicamente, para encontrar los nombres y los valores actuales de todos los parámetros para un modelo dado, podemos usar el siguiente método
#
# estimator.get_params ()
#
# Una búsqueda consta de:
#
# * un modelo (regresor o clasificador como sklearn.svm.SVC ());
# * un espacio de parámetros;
# * un método para buscar o muestrear candidatos;
# * un esquema de validación cruzada;
# * una función de puntuación - metrica.
#
# Algunos modelos permiten estrategias de búsqueda de parámetros especializadas y eficientes, que se describen a continuación.
#
# En scikit-learn se proporcionan dos enfoques genéricos para muestrear candidatos de búsqueda:
#
#
# <img src="https://developer.qualcomm.com/sites/default/files/attachments/learning_resources_03-05.png" width="500" height="270" >
#
#
# **GridSearchCV:** La búsqueda de cuadrícula proporcionada por GridSearchCV genera exhaustivamente candidatos a partir de una cuadrícula de valores de parámetros especificados con el parámetro param_grid. Por ejemplo, el siguiente param_grid especifica que tiene una cuadrícula para explorar que es un núcleo lineal con valores alfa en [0.0002,0.0003,0.0004,0.0005,0.0006,0.0007,0.0009] y 'max_iter', es decir, un máximo de 10000 iteraciones.
#
# param_grid = {'alpha':[0.01,0.001,0.0001,0.0002,0.0003,0.0004,0.0005,0.0006,0.0007,0.0009],'max_iter':[10000]}
#
# **RandomizedSearchCV:** puede muestrear un número determinado de candidatos de un espacio de parámetros con una distribución específica. Después de describir estas herramientas, detallamos las mejores prácticas aplicables a ambos enfoques.
#
# Tenga en cuenta que es común que un pequeño subconjunto de esos parámetros pueda tener un gran impacto en el rendimiento predictivo o de cálculo del modelo, mientras que otros pueden dejarse con sus valores predeterminados. Se recomienda leer la cadena de documentación de la clase de estimador para comprender mejor su comportamiento esperado.

# %% [markdown]
# ### 6.1 Búsqueda aleatoria/Random Search
#
# En la búsqueda aleatoria, creamos una cuadrícula de hiperparámetros y entrenamos / probamos nuestro modelo en una combinación aleatoria de estos hiperparámetros. En este ejemplo, también decidí realizar una validación cruzada en el conjunto de entrenamiento.
#
# Al realizar tareas de aprendizaje automático, generalmente dividimos nuestro conjunto de datos en conjuntos de entrenamiento y de prueba. Esto se hace para probar nuestro modelo después de haberlo entrenado (de esta manera podemos verificar su rendimiento cuando trabajamos con datos invisibles). Cuando usamos la validación cruzada, dividimos nuestro conjunto de entrenamiento en otras N particiones para asegurarnos de que nuestro modelo no sobreajuste nuestros datos.
#
# Uno de los métodos de validación cruzada más utilizados es la **validación de K-Fold**. En K-Fold, dividimos nuestro conjunto de entrenamiento en N particiones y luego entrenamos iterativamente nuestro modelo usando N-1 particiones y lo probamos con la partición sobrante (en cada iteración cambiamos la partición sobrante). Una vez que hemos entrenado N veces el modelo, promediamos los resultados de entrenamiento obtenidos en cada iteración para obtener nuestros resultados de rendimiento de entrenamiento general.
#
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/f2/K-fold_cross_validation.jpg" width="500" height="270" >
#
# El uso de la validación cruzada al implementar la optimización de hiperparámetros puede ser realmente importante. De esta manera, podríamos evitar el uso de algunos hiperparámetros que funcionan muy bien con los datos de entrenamiento pero no tan bien con los datos de prueba.
# Ahora podemos comenzar a implementar la búsqueda aleatoria desafiando primero una cuadrícula de hiperparámetros que se muestrearán aleatoriamente al llamar a RandomizedSearchCV ().

# %%
#Librerias 
from sklearn import tree
from sklearn.model_selection import KFold
from sklearn.model_selection import RandomizedSearchCV

# %%
scaler = StandardScaler()

    #print(f"Features: {feature_names}\nTarget: {target}")
    
X_train = train_df[feature_names]
scaler.fit(X_train)
    
X_train = scaler.transform(X_train)
y_train = train_df[target]
    
X_test = test_df[feature_names]
X_test = scaler.transform(X_test)
    
y_test = test_df[target]

random_search = {
               'max_depth': [2,3,4,20],
               'max_features': ['log2', 'sqrt'],
               'min_samples_leaf': [2,4, 6, 8],
               'min_samples_split': [2, 5, 7,10,20]}
kf = KFold(n_splits=2)
model = tree.DecisionTreeRegressor()
regression_scores_DT_Aleatoria = {}
target = 'PM2.5'
model_dt = RandomizedSearchCV(estimator = model,  param_distributions = random_search, n_iter = 20, 
                               cv = 10, verbose=True, random_state= 102, n_jobs = 3)
model_dt.fit(X_train, y_train)

feature_names = ['hour', 'day_week'] +  ['Latitud', 'Longitud'] + ['PM10','CO','NO2','NOX','NO','OZONO']
    
regression_scores_DT_Aleatoria['model_with_day_hour'] = regression_model(feature_names, target, model)

print(regression_scores_DT_Aleatoria)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
#
# Model Score: 0.472077840121363
# {'model_with_day_hour': {'MSE': 82.8695579964269, 'MAE': 6.315850592205387}}

# %%
#rows_of_day = df.apply(lambda row : row['month'] == 11 and row['day_month'] == 3 and row['Station']=='USQ', axis=1)
rows_of_day = df.apply(lambda row : row['month'] == 11 and row['day_month'] == 6 and row['Station']=='USQ', axis=1)

single_day_df = df[rows_of_day]

scaler = StandardScaler()
X_train = train_df[feature_names]
scaler.fit(X_train)

X_test = single_day_df[feature_names]
X_test = scaler.transform(X_test)
y_test = single_day_df[target]

y_predicted = model_dt.predict(X_test)
#y_predicted_DT = model1.predict(X_test)

figure(figsize=(10, 5), dpi=80)
draw_example2(single_day_df, y_predicted, [12])

# %%
figure(figsize=(10, 5), dpi=80)
draw_example2(single_day_df,y_predicted, list(range(3, 18)))

# %% [markdown]
# ### 6.1 Búsqueda cuadrícula/Grid Search
#
# En Grid Search, configuramos una cuadrícula de hiperparámetros y entrenamos / probamos nuestro modelo en cada una de las combinaciones posibles.
# Para elegir los parámetros que se utilizarán en la búsqueda de cuadrícula, ahora podemos ver qué parámetros funcionaron mejor con la búsqueda aleatoria y formar una cuadrícula basada en ellos para ver si podemos encontrar una mejor combinación.
#
# - Grid Search se puede implementar en Python usando la función GridSearchCV().

# %%
#Librerias

from sklearn.model_selection import GridSearchCV

# %%
grid_search = {
               'max_depth': [None, 3, 5, 10],
               'max_features': [3, 5, 7, 'sqrt'],
               'min_samples_leaf': [2, 4, 6, 8],
               'min_samples_split': [2, 5, 7, 10],
           
               'min_samples_split': [2, 5, 10]
               }

model = tree.DecisionTreeRegressor()
regression_scores_DT_Cuadricula = {}
target = 'PM2.5'
model_gs = GridSearchCV(estimator = model, param_grid = grid_search, 
                               cv = 5, verbose= 5, n_jobs = -1)
model_gs.fit(X_train,y_train)

feature_names = ['hour', 'day_week'] +  ['Latitud', 'Longitud'] + ['PM10','CO','NO2','NOX','NO','OZONO']
    
regression_scores_DT_Cuadricula['model_with_day_hour'] = regression_model(feature_names, target, model)

print(regression_scores_DT_Cuadricula['model_with_day_hour'])
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.536 total time=   0.5s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.522 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.561 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.547 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.566 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.594 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.578 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.557 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.609 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.590 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.617 total time=   0.5s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.603 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.575 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.616 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.608 total time=   0.3s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.641 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.624 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.616 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.636 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.632 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.635 total time=   0.3s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.628 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.619 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.640 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.643 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.650 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.621 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.624 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.646 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.657 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.530 total time=   0.9s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.514 total time=   1.0s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.508 total time=   0.8s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.553 total time=   0.8s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.542 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.593 total time=   0.6s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.577 total time=   0.7s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.561 total time=   0.9s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.601 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.595 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.609 total time=   0.7s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.602 total time=   0.7s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.582 total time=   0.7s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.610 total time=   0.7s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.610 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.634 total time=   0.7s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.630 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.608 total time=   0.7s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.630 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.633 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.640 total time=   0.9s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.625 total time=   0.8s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.614 total time=   1.2s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.642 total time=   1.3s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.652 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.661 total time=   0.6s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.648 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.630 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.652 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.649 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.535 total time=   0.9s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.532 total time=   0.9s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.516 total time=   1.1s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.543 total time=   1.1s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.534 total time=   0.9s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.587 total time=   0.9s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.566 total time=   0.9s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.564 total time=   0.9s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.598 total time=   1.3s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.537 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.541 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.520 total time=   0.5s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.537 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.534 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.577 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.583 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.617 total time=   0.5s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.595 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.587 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.605 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.609 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.600 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.601 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.589 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.628 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.636 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.641 total time=   0.5s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.623 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.615 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.639 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.620 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.653 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.642 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.636 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.639 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.617 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.665 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.635 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.630 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.543 total time=   0.9s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.525 total time=   1.0s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.550 total time=   0.9s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.522 total time=   0.7s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.527 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.586 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.589 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.608 total time=   0.8s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.589 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.587 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.607 total time=   0.7s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.595 total time=   0.8s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.617 total time=   0.7s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.600 total time=   0.7s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.592 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.637 total time=   0.7s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.633 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.646 total time=   0.7s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.625 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.616 total time=   0.7s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.639 total time=   1.0s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.638 total time=   0.8s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.661 total time=   1.2s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.644 total time=   1.3s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.632 total time=   0.7s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.651 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.648 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.662 total time=   0.6s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.645 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.630 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.529 total time=   0.9s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.527 total time=   1.0s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.547 total time=   1.1s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.532 total time=   1.0s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.509 total time=   0.9s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.582 total time=   0.9s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.574 total time=   1.0s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.606 total time=   0.9s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.582 total time=   1.3s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.595 total time=   1.2s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.604 total time=   1.2s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.588 total time=   0.9s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.579 total time=   0.8s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.603 total time=   0.8s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.604 total time=   0.8s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.634 total time=   0.8s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.634 total time=   0.8s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.610 total time=   0.9s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=5;, score=0.637 total time=   0.8s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=5;, score=0.632 total time=   1.1s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=10;, score=0.634 total time=   0.8s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=10;, score=0.613 total time=   0.8s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=10;, score=0.610 total time=   0.8s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=2;, score=0.651 total time=   1.1s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=2;, score=0.646 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=5;, score=0.653 total time=   0.8s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=5;, score=0.640 total time=   0.7s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=5;, score=0.629 total time=   0.7s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=10;, score=0.650 total time=   0.7s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=10;, score=0.656 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.532 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.534 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.533 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.539 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.542 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.590 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.580 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.570 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.597 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.595 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.608 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.606 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.583 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.609 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.605 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=2;, score=0.647 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=2;, score=0.626 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=2;, score=0.622 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=5;, score=0.629 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=5;, score=0.633 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=10;, score=0.630 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=10;, score=0.625 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.646 total time=   0.3s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.628 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.621 total time=   0.3s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.640 total time=   0.3s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.628 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.633 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.636 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.635 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.419 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.454 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.513 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.303 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.287 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.500 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.492 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.330 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.437 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.390 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.466 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.311 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.539 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.439 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.439 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.513 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.554 total time=   0.1s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.577 total time=   1.2s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.600 total time=   1.2s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.596 total time=   0.9s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.610 total time=   0.8s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.592 total time=   0.8s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.591 total time=   0.8s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.640 total time=   0.8s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.624 total time=   0.8s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=5;, score=0.639 total time=   1.0s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=5;, score=0.623 total time=   0.8s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=5;, score=0.614 total time=   1.1s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=10;, score=0.630 total time=   0.8s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=6, min_samples_split=10;, score=0.625 total time=   0.8s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=2;, score=0.655 total time=   0.8s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=2;, score=0.640 total time=   1.1s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=2;, score=0.629 total time=   0.7s
# [CV 2/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=5;, score=0.654 total time=   0.8s
# [CV 4/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=5;, score=0.655 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=10;, score=0.661 total time=   0.7s
# [CV 3/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=10;, score=0.644 total time=   0.7s
# [CV 5/5] END max_depth=None, max_features=7, min_samples_leaf=8, min_samples_split=10;, score=0.640 total time=   0.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.540 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.521 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.531 total time=   0.6s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.533 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.511 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.594 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.587 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.610 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.598 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.576 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.602 total time=   0.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.597 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.604 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.611 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.595 total time=   0.3s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=2;, score=0.621 total time=   0.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=2;, score=0.638 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=5;, score=0.626 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=5;, score=0.623 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=5;, score=0.610 total time=   0.3s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=10;, score=0.616 total time=   0.3s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=10;, score=0.629 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=10;, score=0.627 total time=   0.3s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.649 total time=   0.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.645 total time=   0.3s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.668 total time=   0.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.653 total time=   0.3s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.647 total time=   0.3s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.655 total time=   0.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.641 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.357 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.340 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.407 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.308 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.511 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.398 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.199 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.511 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.424 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.501 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.290 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.447 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.469 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.361 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.359 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.422 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.559 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.476 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.326 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.512 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.314 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.457 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.517 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.373 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.491 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.482 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.478 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.416 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.375 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.459 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.525 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.573 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.378 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.572 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.526 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.575 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.535 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.494 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.429 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.558 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.587 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.588 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.582 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.571 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.350 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.575 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.473 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.516 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.461 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.498 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.519 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.424 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.580 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.523 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.553 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.571 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.453 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.461 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.438 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.559 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.416 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.579 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.563 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.586 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.566 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.551 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.580 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.533 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.523 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.568 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.578 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.528 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.398 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.574 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.496 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.576 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.561 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=5;, score=0.582 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=5;, score=0.582 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=5;, score=0.572 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=10;, score=0.581 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=10;, score=0.588 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=10;, score=0.515 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=8, min_samples_split=2;, score=0.575 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=8, min_samples_split=2;, score=0.491 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=8, min_samples_split=5;, score=0.588 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=8, min_samples_split=5;, score=0.580 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=8, min_samples_split=5;, score=0.563 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.410 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.500 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.527 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.484 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.454 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.410 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.472 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.398 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.322 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.497 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.448 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.441 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.549 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.583 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.486 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.481 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.510 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.471 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.503 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.574 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.384 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.510 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.534 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.539 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.486 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.343 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.504 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.584 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.561 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.455 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.512 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.526 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.515 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.560 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.529 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.489 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.368 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.519 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.364 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.473 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.544 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.536 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.506 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.578 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.586 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=2;, score=0.534 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.580 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=5;, score=0.532 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.554 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.507 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=2, min_samples_split=10;, score=0.517 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.581 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=2;, score=0.581 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.587 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.494 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=5;, score=0.521 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.516 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=7, min_samples_leaf=4, min_samples_split=10;, score=0.579 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.584 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.535 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=2;, score=0.468 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=7, min_samples_leaf=6, min_samples_split=5;, score=0.498 total time=   0.2s
# ...
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=10;, score=0.475 total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.467 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.406 total time=   0.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.487 total time=   0.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.561 total time=   0.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.423 total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.548 total time=   0.1s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.590 total time=   0.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.514 total time=   0.2s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.653 total time=   0.4s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.617 total time=   0.3s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.669 total time=   0.3s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.649 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.597 total time=   0.3s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.662 total time=   0.3s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.660 total time=   0.3s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.658 total time=   0.3s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.645 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.611 total time=   0.3s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.662 total time=   0.3s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.659 total time=   0.3s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.594 total time=   0.3s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.637 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.650 total time=   0.3s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.650 total time=   0.3s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.607 total time=   0.3s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.634 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.655 total time=   0.4s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.622 total time=   0.4s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.643 total time=   0.3s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.659 total time=   0.4s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.614 total time=   0.3s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.636 total time=   0.3s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.617 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.662 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.636 total time=   0.6s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.648 total time=   0.3s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.621 total time=   0.3s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.674 total time=   0.4s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.661 total time=   0.4s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.676 total time=   0.4s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.684 total time=   0.4s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.684 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.664 total time=   0.5s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.654 total time=   0.4s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.683 total time=   0.4s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.670 total time=   0.4s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.684 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.669 total time=   0.4s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.659 total time=   0.4s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.680 total time=   0.4s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.685 total time=   0.5s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.687 total time=   0.5s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.668 total time=   0.6s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.645 total time=   0.4s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.678 total time=   0.6s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.684 total time=   0.5s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.680 total time=   0.5s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.673 total time=   0.4s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.664 total time=   0.5s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.668 total time=   0.4s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.683 total time=   0.5s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.686 total time=   0.5s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.678 total time=   0.4s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.666 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=5;, score=0.594 total time=   0.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=5;, score=0.540 total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=10;, score=0.600 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=10;, score=0.412 total time=   0.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.548 total time=   0.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.531 total time=   0.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.577 total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.571 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.550 total time=   0.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.417 total time=   0.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.510 total time=   0.2s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.652 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.607 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=2;, score=0.643 total time=   0.3s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.669 total time=   0.3s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=5;, score=0.643 total time=   0.3s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.655 total time=   0.3s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.642 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=2, min_samples_split=10;, score=0.631 total time=   0.3s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.666 total time=   0.2s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=2;, score=0.668 total time=   0.3s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.649 total time=   0.3s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.651 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5;, score=0.619 total time=   0.3s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.631 total time=   0.3s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10;, score=0.596 total time=   0.3s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.633 total time=   0.3s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.597 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=2;, score=0.628 total time=   0.4s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.644 total time=   0.4s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=5;, score=0.666 total time=   0.4s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.666 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.658 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=6, min_samples_split=10;, score=0.642 total time=   0.3s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.638 total time=   0.3s
# [CV 3/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.661 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=2;, score=0.644 total time=   0.3s
# [CV 2/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.662 total time=   0.3s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=5;, score=0.620 total time=   0.6s
# [CV 1/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.660 total time=   0.3s
# [CV 4/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.664 total time=   0.3s
# [CV 5/5] END max_depth=10, max_features=3, min_samples_leaf=8, min_samples_split=10;, score=0.633 total time=   0.3s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.674 total time=   0.4s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=2;, score=0.689 total time=   0.4s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.682 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.668 total time=   0.4s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=5;, score=0.663 total time=   0.4s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.678 total time=   0.4s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=10;, score=0.666 total time=   0.4s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.683 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=2;, score=0.656 total time=   0.4s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.666 total time=   0.4s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.684 total time=   0.4s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.669 total time=   0.4s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=4, min_samples_split=10;, score=0.633 total time=   0.5s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.673 total time=   0.5s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=2;, score=0.670 total time=   0.6s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.686 total time=   0.5s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.669 total time=   0.5s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=5;, score=0.652 total time=   0.5s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.680 total time=   0.5s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=6, min_samples_split=10;, score=0.682 total time=   0.4s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.687 total time=   0.5s
# [CV 3/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.673 total time=   0.4s
# [CV 5/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=2;, score=0.667 total time=   0.5s
# [CV 2/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.681 total time=   0.5s
# [CV 4/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=5;, score=0.676 total time=   0.4s
# [CV 1/5] END max_depth=10, max_features=5, min_samples_leaf=8, min_samples_split=10;, score=0.688 total time=   0.4s
#
# Model Score: 0.47707784773454354
# {'MSE': 82.08469149076953, 'MAE': 6.297819757824389}

# %%
#rows_of_day = df.apply(lambda row : row['month'] == 11 and row['day_month'] == 3 and row['Station']=='USQ', axis=1)
rows_of_day = df.apply(lambda row : row['month'] == 11 and row['day_month'] == 6 and row['Station']=='USQ', axis=1)

single_day_df = df[rows_of_day]

scaler = StandardScaler()
X_train = train_df[feature_names]
scaler.fit(X_train)

X_test = single_day_df[feature_names]
X_test = scaler.transform(X_test)
y_test = single_day_df[target]

y_predicted = model_dt.predict(
    X_test)
#y_predicted_DT = model1.predict(X_test)

figure(figsize=(10, 5), dpi=80)
draw_example2(single_day_df, y_predicted, [12])

# %%
figure(figsize=(10, 5), dpi=80)
draw_example2(single_day_df,y_predicted, list(range(3, 18)))

# %% [markdown]
# ## 7. Comparar modelos

# %%
models_cross = pd.DataFrame({
    'Model': ['Aleatorio MAE'],
    'accuracy': [regression_scores_DT_Aleatoria['model_with_day_hour']['MAE']],
    })
 
    
    
models_cross.sort_values(by='accuracy', ascending=False)
# Out:
#            Model  accuracy
# 0  Aleatorio MAE  6.315851
